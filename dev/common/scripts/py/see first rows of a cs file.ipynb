# %%
import polars as pl

# Path to the compressed CSV file
csv_path = "D:/source/cs1850.csv.gz"

# Read only the first 10 rows
df = pl.read_csv(csv_path, n_rows=10)

# Display column headers
print("Column headers:")
print(df.columns)

# Display first 10 rows
print("\nFirst 10 rows:")
print(df)
# Out:
# Column headers:
# ['cenyear', 'serial', 'histid', 'hik', 'hhtype', 'histid_head', 'relate', 'birthyr', 'sex', 'race', 'bpl', 'histid_sp', 'histid_pop', 'histid_mom', 'steppop', 'stepmom', 'stateicp', 'countyicp', 'farm', 'urban', 'sizepl']
#
# First 10 rows:
# shape: (10, 21)
# ┌─────────┬────────┬───────────────────┬───────────────────┬───┬───────────┬──────┬───────┬────────┐
# │ cenyear ┆ serial ┆ histid            ┆ hik               ┆ … ┆ countyicp ┆ farm ┆ urban ┆ sizepl │
# │ ---     ┆ ---    ┆ ---               ┆ ---               ┆   ┆ ---       ┆ ---  ┆ ---   ┆ ---    │
# │ i64     ┆ i64    ┆ str               ┆ str               ┆   ┆ i64       ┆ i64  ┆ i64   ┆ i64    │
# ╞═════════╪════════╪═══════════════════╪═══════════════════╪═══╪═══════════╪══════╪═══════╪════════╡
# │ 1850    ┆ 127574 ┆ 08AD25D8-9761-465 ┆ ZMis5eUkqdGFvRZP3 ┆ … ┆ 10        ┆ 2    ┆ 1     ┆ 1      │
# │         ┆        ┆ 6-A157-62AFCD…    ┆ mO79              ┆   ┆           ┆      ┆       ┆        │
# ...
