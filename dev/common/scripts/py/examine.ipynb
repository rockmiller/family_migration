# %%
import pandas as pd
from pathlib import Path

filename = 'usa_00034.csv'
location = Path(r"C:\Users\rockm\local\ipums_census\raw_1880")
check = location / filename

df = pd.read_csv(check, nrows=100)
print(df.columns)
# Out:
# Index(['YEAR', 'SERIAL', 'NUMPREC', 'NUMPERHH', 'HHTYPE', 'STATEICP',
#        'COUNTYICP', 'SIZEPL', 'URBAN', 'GQ', 'GQTYPE', 'GQTYPED', 'FARM',
#        'NFAMS', 'NCOUPLES', 'NMOTHERS', 'NFATHERS', 'MULTGEN', 'MULTGEND',
#        'SLAVEHH', 'ENUMDIST', 'SPLIT', 'SPLITHID', 'SPLITNUM', 'PERNUM',
#        'FAMUNIT', 'FAMSIZE', 'MOMLOC', 'STEPMOM', 'MOMRULE_HIST', 'POPLOC',
#        'STEPPOP', 'POPRULE_HIST', 'SPLOC', 'SPRULE_HIST', 'NCHILD', 'NCHLT5',
#        'NSIBS', 'ELDCH', 'YNGCH', 'RELATE', 'RELATED', 'IMPREL', 'SEX', 'AGE',
#        'BIRTHYR', 'RACE', 'RACED', 'BPL', 'BPLD', 'MBPL', 'MBPLD', 'FBPL',
#        'FBPLD', 'NATIVITY', 'CITIZEN', 'SCHOOL', 'LABFORCE', 'OCC1950',
#        'VERSIONHIST', 'HISTID', 'SURSIM', 'SLAVENUM', 'SLAVEOWN',
#        'SLAVEHOLDINGS', 'HIK', 'LINK1850', 'LINK1860', 'LINK1870', 'LINK1880',
#        'VERSIONHIK', 'BIRTHYR_HEAD', 'BIRTHYR_MOM', 'BIRTHYR_POP',
#        'BIRTHYR_SP', 'BIRTHYR_MOM2', 'BIRTHYR_POP2', 'HISTID_HEAD',
# ...
